# %% [markdown]
# # Imports

# %%
import random
import numpy as np
from data_process import get_FASHION_data, get_RICE_data
from scipy.spatial import distance
from models import Perceptron, SVM, Softmax, Logistic
from kaggle_submission import output_submission_csv
# %matplotlib inline

# For auto-reloading external modules
# See http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Loading Fashion-MNIST

# %% [markdown]
# In the following cells we determine the number of images for each split and load the images.
# <br />
# TRAIN_IMAGES + VAL_IMAGES = (0, 60000]
# , TEST_IMAGES = 10000

# %%
# You can change these numbers for experimentation
# For submission we will use the default values 
TRAIN_IMAGES = 50000
VAL_IMAGES = 10000
normalize = True

# %%
data = get_FASHION_data(TRAIN_IMAGES, VAL_IMAGES, normalize=normalize)
X_train_fashion, y_train_fashion = data['X_train'], data['y_train']
X_val_fashion, y_val_fashion = data['X_val'], data['y_val']
X_test_fashion, y_test_fashion = data['X_test'], data['y_test']
n_class_fashion = len(np.unique(y_test_fashion))

# %% [markdown]
# # Loading Rice

# %%
# loads train / test / val splits of 80%, 20%, 20% 
data = get_RICE_data()
X_train_RICE, y_train_RICE = data['X_train'], data['y_train']
X_val_RICE, y_val_RICE = data['X_val'], data['y_val']
X_test_RICE, y_test_RICE = data['X_test'], data['y_test']
n_class_RICE = len(np.unique(y_test_RICE))

print("Number of train samples: ", X_train_RICE.shape[0])
print("Number of val samples: ", X_val_RICE.shape[0])
print("Number of test samples: ", X_test_RICE.shape[0])
# Out:
# Number of train samples:  10911
# Number of val samples:  3637
# Number of test samples:  3637

# %% [markdown]
# ### Get Accuracy

# %% [markdown]
# This function computes how well your model performs using accuracy as a metric.

# %%
def get_acc(pred, y_test):
    return np.sum(y_test == pred) / len(y_test) * 100

# %% [markdown]
# # Perceptron

# %% [markdown]
# Perceptron has 2 hyperparameters, "learning rate" and "number of epochs" that you can experiment with:
# ### Hyperparameter 1: Learning rate
# The learning rate controls how much we change the current weights of the classifier during each update. We set it at a default value of 0.5, but you should experiment with different values. Here is a guide to help you find a right learning rate:
# - Try values ranging from 0.0005 to 5.0 to see the impact on model accuracy.
# - If the loss oscillates a lot or the loss diverges, the learning rate may be too high. Try decreasing it by a factor of 10 (e.g. from 0.5 to 0.05).
# - If the loss decreases very slowly, the learning rate may be too low and the training can take a long time. Try increasing it by a factor of 10.
# - You can also try adding a learning rate decay to slowly reduce the learning rate over each training epoch. For example, multiply the learning rate by 0.95 after each epoch.
# - Plot training and validation accuracy over epochs for different learning rates. This will help you visualize the impact of the learning rate.
# - [Here](https://towardsdatascience.com/https-medium-com-dashingaditya-rakhecha-understanding-learning-rate-dd5da26bb6de) is a detailed guide to learning rate.
#
# ### Hyperparameter 2: Number of Epochs
# - An epoch is a complete iterative pass over the training dataset. During an epoch we predict a label using the classifier and then update the weights of the classifier according to the perceptron update rule for each sample in the training set.
# - By observing the training and validation accuracy graphs, you can determine if the model has converged or not. Try increasing the number of epochs if the model is not converging or has low accuracy.
# - You should try different values for the number of training epochs and report your results.

# %% [markdown]
# In this section, you will implement the Perceptron classifier in the **models/perceptron.py** script.
#
# The following code:
# - Creates an instance of the Perceptron classifier class
# - An instance of the Perceptron class is trained on the training data using its train method.
# - We use the predict method to find the training accuracy as well as the testing accuracy

# %% [markdown]
# ## Train Perceptron on Fashion-MNIST

# %%
lr = 0.7
n_epochs = 30
batch_size = 150
percept_fashion = Perceptron(n_class_fashion, lr, n_epochs, batch_size)

# - Refer to hints in the train method of the Perceptron class in "models/perceptron.py"
percept_fashion.train(X_train_fashion, y_train_fashion)
# Out:
# Epoch 0 accuracy 8.44%
# Epoch 1 accuracy 79.11%
# Epoch 2 accuracy 81.12%
# Epoch 3 accuracy 82.41%
# Epoch 4 accuracy 83.09%
# Epoch 5 accuracy 83.35%
# Epoch 6 accuracy 82.42%
# Epoch 7 accuracy 83.56%
# Epoch 8 accuracy 82.05%
# Epoch 9 accuracy 84.06%
# Epoch 10 accuracy 83.30%
# Epoch 11 accuracy 82.09%
# Epoch 12 accuracy 80.87%
# Epoch 13 accuracy 80.68%
# Epoch 14 accuracy 83.66%
# Epoch 15 accuracy 80.15%
# Epoch 16 accuracy 83.96%
# Epoch 17 accuracy 82.03%
# Epoch 18 accuracy 83.34%
# Epoch 19 accuracy 84.32%
# Epoch 20 accuracy 83.66%
# Epoch 21 accuracy 84.68%
# Epoch 22 accuracy 81.80%
# Epoch 23 accuracy 83.50%
# Epoch 24 accuracy 82.40%
# Epoch 25 accuracy 81.86%
# Epoch 26 accuracy 82.73%
# Epoch 27 accuracy 84.97%
# Epoch 28 accuracy 82.41%
# Epoch 29 accuracy 84.52%

# %%
pred_percept = percept_fashion.predict(X_train_fashion)
print('The training accuracy is given by: %f' % (get_acc(pred_percept, y_train_fashion)))
# Out:
# The training accuracy is given by: 85.326000

# %% [markdown]
# ### Validate Perceptron on Fashion-MNIST

# %%
pred_percept = percept_fashion.predict(X_val_fashion)
print('The validation accuracy is given by: %f' % (get_acc(pred_percept, y_val_fashion)))
# Out:
# The validation accuracy is given by: 83.020000

# %% [markdown]
# ### Test Perceptron on Fashion-MNIST

# %%
pred_percept = percept_fashion.predict(X_test_fashion)
print('The testing accuracy is given by: %f' % (get_acc(pred_percept, y_test_fashion)))
# Out:
# The testing accuracy is given by: 81.620000

# %% [markdown]
# ### Perceptron_Fashion-MNIST Kaggle Submission
#
# Once you are satisfied with your solution and test accuracy, output a file to submit your test set predictions to the Kaggle for Assignment 1 Fashion-MNIST. Use the following code to do so:

# %%
output_submission_csv('kaggle/perceptron_submission_fashion.csv', percept_fashion.predict(X_test_fashion))

# %% [markdown]
# ## Train Perceptron on Rice

# %%
lr = 0.5
n_epochs = 50
batch_size = 20

percept_RICE = Perceptron(n_class_RICE, lr, n_epochs, batch_size)
percept_RICE.train(X_train_RICE, y_train_RICE)
# Out:
# Epoch 0 accuracy 45.22%
# Epoch 1 accuracy 79.47%
# Epoch 2 accuracy 80.45%
# Epoch 3 accuracy 80.38%
# Epoch 4 accuracy 72.80%
# Epoch 5 accuracy 62.21%
# Epoch 6 accuracy 82.73%
# Epoch 7 accuracy 83.37%
# Epoch 8 accuracy 78.32%
# Epoch 9 accuracy 84.91%
# Epoch 10 accuracy 74.05%
# Epoch 11 accuracy 82.32%
# Epoch 12 accuracy 68.55%
# Epoch 13 accuracy 75.06%
# Epoch 14 accuracy 89.55%
# Epoch 15 accuracy 86.03%
# Epoch 16 accuracy 83.33%
# Epoch 17 accuracy 76.11%
# Epoch 18 accuracy 79.16%
# Epoch 19 accuracy 89.33%
# Epoch 20 accuracy 89.43%
# Epoch 21 accuracy 69.61%
# Epoch 22 accuracy 65.72%
# Epoch 23 accuracy 93.21%
# Epoch 24 accuracy 88.67%
# Epoch 25 accuracy 66.85%
# Epoch 26 accuracy 73.01%
# Epoch 27 accuracy 87.05%
# Epoch 28 accuracy 96.54%
# Epoch 29 accuracy 85.55%
# Epoch 30 accuracy 89.17%
# Epoch 31 accuracy 97.63%
# Epoch 32 accuracy 72.40%
# Epoch 33 accuracy 99.32%
# Epoch 34 accuracy 50.26%
# Epoch 35 accuracy 63.37%
# Epoch 36 accuracy 94.37%
# Epoch 37 accuracy 94.38%
# Epoch 38 accuracy 99.11%
# Epoch 39 accuracy 98.62%
# Epoch 40 accuracy 99.55%
# Epoch 41 accuracy 98.49%
# Epoch 42 accuracy 92.23%
# Epoch 43 accuracy 98.35%
# Epoch 44 accuracy 98.87%
# Epoch 45 accuracy 96.58%
# Epoch 46 accuracy 99.21%
# Epoch 47 accuracy 96.73%
# Epoch 48 accuracy 99.86%
# Epoch 49 accuracy 99.09%

# %%
pred_percept = percept_RICE.predict(X_train_RICE)
print('The training accuracy is given by: %f' % (get_acc(pred_percept, y_train_RICE)))
# Out:
# The training accuracy is given by: 99.835029

# %% [markdown]
# ### Validate Perceptron on Rice

# %%
pred_percept = percept_RICE.predict(X_val_RICE)
print('The validation accuracy is given by: %f' % (get_acc(pred_percept, y_val_RICE)))
# Out:
# The validation accuracy is given by: 99.752543

# %% [markdown]
# ### Test Perceptron on Rice

# %%
pred_percept = percept_RICE.predict(X_test_RICE)
print('The testing accuracy is given by: %f' % (get_acc(pred_percept, y_test_RICE)))
# Out:
# The testing accuracy is given by: 99.752543

# %% [markdown]
# # Support Vector Machines (with SGD)

# %% [markdown]
# Next, you will implement a "soft margin" SVM. In this formulation you will maximize the margin between positive and negative training examples and penalize margin violations using a hinge loss.
#
# We will optimize the SVM loss using SGD. This means you must compute the loss function with respect to model weights. You will use this gradient to update the model weights.
#
# SVM optimized with SGD has 3 hyperparameters that you can experiment with:
# - **Learning rate** - similar to as defined above in Perceptron, this parameter scales by how much the weights are changed according to the calculated gradient update.
# - **Epochs** - similar to as defined above in Perceptron.
# - **Regularization constant** - Hyperparameter to determine the strength of regularization. In this case it is a coefficient on the term which maximizes the margin. You could try different values. The default value is set to 0.05.

# %% [markdown]
# You will implement the SVM using SGD in the **models/svm.py**
#
# The following code:
# - Creates an instance of the SVM classifier class
# - The train function of the SVM class is trained on the training data
# - We use the predict function to find the training accuracy as well as the testing accuracy

# %% [markdown]
# ## Train SVM on Fashion-MNIST

# %%
# Adjust the following three hyperparameters to achieve the best accuracy:
lr = 0.5
n_epochs = 15
reg_const = 0.05
batch_size=500

svm_fashion = SVM(n_class_fashion, lr, n_epochs, reg_const,batch_size)

# Refer to hints in the calculate_gradient and train methods of the SVM class in "models/svm.py"
svm_fashion.train(X_train_fashion, y_train_fashion)
# Out:
# Epoch 0 accuracy 13.048000000000002 %
# Epoch 1 accuracy 75.09400000000001 %
# Epoch 2 accuracy 78.514 %
# Epoch 3 accuracy 75.182 %
# Epoch 4 accuracy 65.29599999999999 %
# Epoch 5 accuracy 83.55799999999999 %
# Epoch 6 accuracy 82.214 %
# Epoch 7 accuracy 78.764 %
# Epoch 8 accuracy 81.322 %
# Epoch 9 accuracy 77.542 %
# Epoch 10 accuracy 82.904 %
# Epoch 11 accuracy 79.782 %
# Epoch 12 accuracy 84.822 %
# Epoch 13 accuracy 84.276 %
# Epoch 14 accuracy 84.958 %

# %%
pred_svm = svm_fashion.predict(X_train_fashion)
print('The training accuracy is given by: %f' % (get_acc(pred_svm, y_train_fashion)))
# Out:
# The training accuracy is given by: 84.870000

# %% [markdown]
# ### Validate SVM on Fashion-MNIST

# %%
pred_svm = svm_fashion.predict(X_val_fashion)
print('The validation accuracy is given by: %f' % (get_acc(pred_svm, y_val_fashion)))
# Out:
# The validation accuracy is given by: 82.900000

# %% [markdown]
# ### Test SVM on Fashion-MNIST

# %%
pred_svm = svm_fashion.predict(X_test_fashion)
print('The testing accuracy is given by: %f' % (get_acc(pred_svm, y_test_fashion)))
# Out:
# The testing accuracy is given by: 81.560000

# %% [markdown]
# ### SVM_Fashion-MNIST Kaggle Submission
#
# Once you are satisfied with your solution and test accuracy output a file to submit your test set predictions to the Kaggle for Assignment 1 Fashion-MNIST. Use the following code to do so:

# %%
output_submission_csv('kaggle/svm_submission_fashion.csv', svm_fashion.predict(X_test_fashion))

# %% [markdown]
# ## Train SVM on Rice

# %%
# Adjust the following three hyperparameters to achieve the best accuracy: 
lr = 0.5
n_epochs = 20
reg_const = 0.05
batch_size=100
svm_RICE = SVM(n_class_RICE, lr, n_epochs, reg_const, batch_size)
svm_RICE.train(X_train_RICE, y_train_RICE)
# Out:
# Epoch 0 accuracy 45.220419759875355 %
# Epoch 1 accuracy 72.2573549628815 %
# Epoch 2 accuracy 78.1779855192008 %
# Epoch 3 accuracy 78.86536522775181 %
# Epoch 4 accuracy 55.06369718632572 %
# Epoch 5 accuracy 60.86518192649619 %
# Epoch 6 accuracy 79.75437631747778 %
# Epoch 7 accuracy 79.03033635780406 %
# Epoch 8 accuracy 69.60865181926496 %
# Epoch 9 accuracy 78.84703510219046 %
# Epoch 10 accuracy 79.32361836678581 %
# Epoch 11 accuracy 81.60571899917515 %
# Epoch 12 accuracy 75.63926312895244 %
# Epoch 13 accuracy 83.38374117862706 %
# Epoch 14 accuracy 77.93052882412245 %
# Epoch 15 accuracy 78.16882045642014 %
# Epoch 16 accuracy 99.16597928695812 %
# Epoch 17 accuracy 99.79836861882504 %
# Epoch 18 accuracy 99.84419393272844 %
# Epoch 19 accuracy 99.83502886994776 %

# %%
pred_svm = svm_RICE.predict(X_train_RICE)
print('The training accuracy is given by: %f' % (get_acc(pred_svm, y_train_RICE)))
# Out:
# The training accuracy is given by: 99.853359

# %% [markdown]
# ### Validate SVM on Rice

# %%
pred_svm = svm_RICE.predict(X_val_RICE)
print('The validation accuracy is given by: %f' % (get_acc(pred_svm, y_val_RICE)))
# Out:
# The validation accuracy is given by: 99.780038

# %% [markdown]
# ## Test SVM on Rice

# %%
pred_svm = svm_RICE.predict(X_test_RICE)
print('The testing accuracy is given by: %f' % (get_acc(pred_svm, y_test_RICE)))
# Out:
# The testing accuracy is given by: 99.807534

# %% [markdown]
# # Softmax Classifier (with SGD)

# %% [markdown]
# Next, you will train a Softmax classifier. This classifier consists of a linear function of the input data followed by a softmax function which outputs a vector of dimension C (number of classes) for each data point. Each entry of the softmax output vector corresponds to a confidence in one of the C classes, and like a probability distribution, the entries of the output vector sum to 1. We use a cross-entropy loss on this sotmax output to train the model.
#
# Check the following link as an additional resource on softmax classification: http://cs231n.github.io/linear-classify/#softmax
#
# Once again we will train the classifier with SGD. This means you need to compute the gradients of the softmax cross-entropy loss function according to the weights and update the weights using this gradient. Check the following link to help with implementing the gradient updates: https://deepnotes.io/softmax-crossentropy

# %% [markdown]
# The softmax classifier has 3 hyperparameters that you can experiment with:
# - **Learning rate** - As above, this controls how much the model weights are updated with respect to their gradient.
# - **Number of Epochs** - As described for perceptron.
# - **Regularization constant** - Hyperparameter to determine the strength of regularization. In this case, we minimize the L2 norm of the model weights as regularization, so the regularization constant is a coefficient on the L2 norm in the combined cross-entropy and regularization objective.

# %% [markdown]
# You will implement a softmax classifier using SGD in the **models/softmax.py**
#
# The following code:
# - Creates an instance of the Softmax classifier class
# - The train function of the Softmax class is trained on the training data
# - We use the predict function to find the training accuracy as well as the testing accuracy

# %% [markdown]
# ## Train Softmax on Fashion-MNIST

# %%
lr = 0.001
n_epochs = 200
reg_const = 0.7
batch_size=128
softmax_fashion = Softmax(n_class_fashion, lr, n_epochs, reg_const, batch_size)

# Refer to hints in the calculate_gradient and train methods of the Softmax class in "models/softmax.py"
softmax_fashion.train(X_train_fashion, y_train_fashion)
# Out:
# Epoch 0 accuracy 6.016 %
# Epoch 1 accuracy 76.24600000000001 %
# Epoch 2 accuracy 79.79 %
# Epoch 3 accuracy 76.27000000000001 %
# Epoch 4 accuracy 79.494 %
# Epoch 5 accuracy 79.002 %
# Epoch 6 accuracy 73.976 %
# Epoch 7 accuracy 79.674 %
# Epoch 8 accuracy 83.43 %
# Epoch 9 accuracy 76.706 %
# Epoch 10 accuracy 79.352 %
# Epoch 11 accuracy 76.24 %
# Epoch 12 accuracy 81.486 %
# Epoch 13 accuracy 77.432 %
# Epoch 14 accuracy 76.778 %
# Epoch 15 accuracy 81.07 %
# Epoch 16 accuracy 82.704 %
# Epoch 17 accuracy 79.01 %
# Epoch 18 accuracy 82.498 %
# Epoch 19 accuracy 81.384 %
# Epoch 20 accuracy 78.712 %
# Epoch 21 accuracy 81.706 %
# Epoch 22 accuracy 77.41 %
# Epoch 23 accuracy 78.57 %
# Epoch 24 accuracy 79.328 %
# Epoch 25 accuracy 78.11200000000001 %
# Epoch 26 accuracy 78.16199999999999 %
# Epoch 27 accuracy 78.88 %
# Epoch 28 accuracy 81.296 %
# Epoch 29 accuracy 79.316 %
# Epoch 30 accuracy 82.45599999999999 %
# Epoch 31 accuracy 81.918 %
# Epoch 32 accuracy 81.03399999999999 %
# Epoch 33 accuracy 81.918 %
# Epoch 34 accuracy 72.41 %
# Epoch 35 accuracy 83.434 %
# Epoch 36 accuracy 82.048 %
# Epoch 37 accuracy 77.714 %
# Epoch 38 accuracy 79.752 %
# Epoch 39 accuracy 78.864 %
# Epoch 40 accuracy 80.706 %
# Epoch 41 accuracy 82.938 %
# Epoch 42 accuracy 83.916 %
# Epoch 43 accuracy 83.818 %
# Epoch 44 accuracy 78.9 %
# Epoch 45 accuracy 81.45599999999999 %
# Epoch 46 accuracy 83.622 %
# Epoch 47 accuracy 82.396 %
# Epoch 48 accuracy 75.8 %
# Epoch 49 accuracy 79.238 %
# Epoch 50 accuracy 82.854 %
# Epoch 51 accuracy 82.216 %
# Epoch 52 accuracy 85.244 %
# Epoch 53 accuracy 85.48 %
# Epoch 54 accuracy 84.574 %
# Epoch 55 accuracy 80.16799999999999 %
# Epoch 56 accuracy 79.192 %
# Epoch 57 accuracy 86.694 %
# Epoch 58 accuracy 85.676 %
# Epoch 59 accuracy 83.694 %
# Epoch 60 accuracy 86.824 %
# Epoch 61 accuracy 85.256 %
# Epoch 62 accuracy 82.91 %
# Epoch 63 accuracy 77.35600000000001 %
# Epoch 64 accuracy 84.146 %
# Epoch 65 accuracy 86.83800000000001 %
# Epoch 66 accuracy 85.18 %
# Epoch 67 accuracy 85.966 %
# Epoch 68 accuracy 83.452 %
# Epoch 69 accuracy 78.706 %
# Epoch 70 accuracy 86.05000000000001 %
# Epoch 71 accuracy 80.654 %
# Epoch 72 accuracy 86.206 %
# Epoch 73 accuracy 85.856 %
# Epoch 74 accuracy 83.152 %
# Epoch 75 accuracy 86.512 %
# Epoch 76 accuracy 83.902 %
# Epoch 77 accuracy 85.436 %
# Epoch 78 accuracy 86.452 %
# Epoch 79 accuracy 86.324 %
# Epoch 80 accuracy 84.446 %
# Epoch 81 accuracy 86.222 %
# Epoch 82 accuracy 87.67 %
# Epoch 83 accuracy 87.67 %
# Epoch 84 accuracy 87.632 %
# Epoch 85 accuracy 87.234 %
# Epoch 86 accuracy 86.976 %
# Epoch 87 accuracy 87.31400000000001 %
# Epoch 88 accuracy 87.982 %
# Epoch 89 accuracy 87.17399999999999 %
# Epoch 90 accuracy 87.558 %
# Epoch 91 accuracy 87.678 %
# Epoch 92 accuracy 87.684 %
# Epoch 93 accuracy 87.28200000000001 %
# Epoch 94 accuracy 87.91 %
# Epoch 95 accuracy 88.064 %
# Epoch 96 accuracy 87.506 %
# Epoch 97 accuracy 87.054 %
# Epoch 98 accuracy 88.31599999999999 %
# Epoch 99 accuracy 88.156 %
# Epoch 100 accuracy 88.18599999999999 %
# Epoch 101 accuracy 88.004 %
# Epoch 102 accuracy 88.228 %
# Epoch 103 accuracy 88.124 %
# Epoch 104 accuracy 88.214 %
# Epoch 105 accuracy 88.35 %
# Epoch 106 accuracy 88.234 %
# Epoch 107 accuracy 88.23 %
# Epoch 108 accuracy 88.058 %
# Epoch 109 accuracy 88.4 %
# Epoch 110 accuracy 88.324 %
# Epoch 111 accuracy 88.332 %
# Epoch 112 accuracy 88.4 %
# Epoch 113 accuracy 88.34 %
# Epoch 114 accuracy 88.274 %
# Epoch 115 accuracy 88.434 %
# Epoch 116 accuracy 88.352 %
# Epoch 117 accuracy 88.428 %
# Epoch 118 accuracy 88.44800000000001 %
# Epoch 119 accuracy 88.402 %
# Epoch 120 accuracy 88.248 %
# Epoch 121 accuracy 88.354 %
# Epoch 122 accuracy 88.42 %
# Epoch 123 accuracy 88.474 %
# Epoch 124 accuracy 88.474 %
# Epoch 125 accuracy 88.202 %
# Epoch 126 accuracy 88.42 %
# Epoch 127 accuracy 88.428 %
# Epoch 128 accuracy 88.46199999999999 %
# Epoch 129 accuracy 88.496 %
# Epoch 130 accuracy 88.42999999999999 %
# Epoch 131 accuracy 88.386 %
# Epoch 132 accuracy 88.5 %
# Epoch 133 accuracy 88.452 %
# Epoch 134 accuracy 88.476 %
# Epoch 135 accuracy 88.524 %
# Epoch 136 accuracy 88.50200000000001 %
# Epoch 137 accuracy 88.542 %
# Epoch 138 accuracy 88.432 %
# Epoch 139 accuracy 88.444 %
# Epoch 140 accuracy 88.468 %
# Epoch 141 accuracy 88.412 %
# Epoch 142 accuracy 88.456 %
# Epoch 143 accuracy 88.466 %
# Epoch 144 accuracy 88.544 %
# Epoch 145 accuracy 88.486 %
# Epoch 146 accuracy 88.498 %
# Epoch 147 accuracy 88.458 %
# Epoch 148 accuracy 88.488 %
# Epoch 149 accuracy 88.554 %
# Epoch 150 accuracy 88.538 %
# Epoch 151 accuracy 88.482 %
# Epoch 152 accuracy 88.564 %
# Epoch 153 accuracy 88.518 %
# Epoch 154 accuracy 88.5 %
# Epoch 155 accuracy 88.51599999999999 %
# Epoch 156 accuracy 88.504 %
# Epoch 157 accuracy 88.486 %
# Epoch 158 accuracy 88.534 %
# Epoch 159 accuracy 88.55199999999999 %
# Epoch 160 accuracy 88.5 %
# Epoch 161 accuracy 88.488 %
# Epoch 162 accuracy 88.492 %
# Epoch 163 accuracy 88.474 %
# Epoch 164 accuracy 88.536 %
# Epoch 165 accuracy 88.534 %
# Epoch 166 accuracy 88.476 %
# Epoch 167 accuracy 88.52600000000001 %
# Epoch 168 accuracy 88.52799999999999 %
# Epoch 169 accuracy 88.51400000000001 %
# Epoch 170 accuracy 88.496 %
# Epoch 171 accuracy 88.492 %
# Epoch 172 accuracy 88.51599999999999 %
# Epoch 173 accuracy 88.52 %
# Epoch 174 accuracy 88.504 %
# Epoch 175 accuracy 88.506 %
# Epoch 176 accuracy 88.524 %
# Epoch 177 accuracy 88.53999999999999 %
# Epoch 178 accuracy 88.494 %
# Epoch 179 accuracy 88.504 %
# Epoch 180 accuracy 88.506 %
# Epoch 181 accuracy 88.506 %
# Epoch 182 accuracy 88.508 %
# Epoch 183 accuracy 88.504 %
# Epoch 184 accuracy 88.5 %
# Epoch 185 accuracy 88.5 %
# Epoch 186 accuracy 88.51400000000001 %
# Epoch 187 accuracy 88.518 %
# Epoch 188 accuracy 88.492 %
# Epoch 189 accuracy 88.498 %
# Epoch 190 accuracy 88.498 %
# Epoch 191 accuracy 88.498 %
# Epoch 192 accuracy 88.512 %
# Epoch 193 accuracy 88.494 %
# Epoch 194 accuracy 88.506 %
# Epoch 195 accuracy 88.49000000000001 %
# Epoch 196 accuracy 88.524 %
# Epoch 197 accuracy 88.50200000000001 %
# Epoch 198 accuracy 88.508 %
# Epoch 199 accuracy 88.504 %

# %%
pred_softmax = softmax_fashion.predict(X_train_fashion)
print('The training accuracy is given by: %f' % (get_acc(pred_softmax, y_train_fashion)))
# Out:
# The training accuracy is given by: 88.518000

# %% [markdown]
# ### Validate Softmax on Fashion-MNIST

# %%
pred_softmax = softmax_fashion.predict(X_val_fashion)
print('The validation accuracy is given by: %f' % (get_acc(pred_softmax, y_val_fashion)))
# Out:
# The validation accuracy is given by: 84.060000

# %% [markdown]
# ### Testing Softmax on Fashion-MNIST

# %%
pred_softmax = softmax_fashion.predict(X_test_fashion)
print('The testing accuracy is given by: %f' % (get_acc(pred_softmax, y_test_fashion)))
# Out:
# The testing accuracy is given by: 82.980000

# %% [markdown]
# ### Softmax_Fashion-MNIST Kaggle Submission
#
# Once you are satisfied with your solution and test accuracy output a file to submit your test set predictions to the Kaggle for Assignment 1 Fashion-MNIST. Use the following code to do so:

# %%
output_submission_csv('kaggle/softmax_submission_fashion.csv', softmax_fashion.predict(X_test_fashion))

# %% [markdown]
# ## Train Softmax on Rice

# %%
lr = 0.001
n_epochs = 100
reg_const = 0.5
batch_size = 128

softmax_RICE = Softmax(n_class_RICE, lr, n_epochs, reg_const, batch_size)
softmax_RICE.train(X_train_RICE, y_train_RICE)
# Out:
# Epoch 0 accuracy 32.05022454403812 %
# Epoch 1 accuracy 79.00284116946202 %
# Epoch 2 accuracy 72.69727797635413 %
# Epoch 3 accuracy 59.00467418201815 %
# Epoch 4 accuracy 79.55274493630282 %
# Epoch 5 accuracy 61.10347355879387 %
# Epoch 6 accuracy 69.60865181926496 %
# Epoch 7 accuracy 62.670699294290166 %
# Epoch 8 accuracy 79.42443405737329 %
# Epoch 9 accuracy 55.90688296214829 %
# Epoch 10 accuracy 57.61158463935479 %
# Epoch 11 accuracy 58.894693428649994 %
# Epoch 12 accuracy 79.14948217395289 %
# Epoch 13 accuracy 77.97635413802585 %
# Epoch 14 accuracy 59.00467418201815 %
# Epoch 15 accuracy 55.82439739712217 %
# Epoch 16 accuracy 69.34286499862525 %
# Epoch 17 accuracy 60.69104573366327 %
# Epoch 18 accuracy 80.0659884520209 %
# Epoch 19 accuracy 81.44991293190358 %
# Epoch 20 accuracy 71.72578132160206 %
# Epoch 21 accuracy 81.95399138484099 %
# Epoch 22 accuracy 80.33177527266062 %
# Epoch 23 accuracy 72.96306479699386 %
# Epoch 24 accuracy 51.32435157180827 %
# Epoch 25 accuracy 57.26331225368894 %
# Epoch 26 accuracy 68.9029419851526 %
# Epoch 27 accuracy 84.5202089634314 %
# Epoch 28 accuracy 73.50380350105398 %
# Epoch 29 accuracy 83.20043992301348 %
# Epoch 30 accuracy 79.66272568967098 %
# Epoch 31 accuracy 80.69837778388782 %
# Epoch 32 accuracy 85.67500687379709 %
# Epoch 33 accuracy 67.20740537072679 %
# Epoch 34 accuracy 71.2858583081294 %
# Epoch 35 accuracy 55.03620199798369 %
# Epoch 36 accuracy 87.54467968105581 %
# Epoch 37 accuracy 56.25515534781413 %
# Epoch 38 accuracy 56.65841811016406 %
# Epoch 39 accuracy 87.7829713133535 %
# Epoch 40 accuracy 54.779580240124645 %
# Epoch 41 accuracy 61.15846393547796 %
# Epoch 42 accuracy 55.46695994867565 %
# Epoch 43 accuracy 95.80240124644854 %
# Epoch 44 accuracy 99.70671799101824 %
# Epoch 45 accuracy 99.37677573091376 %
# Epoch 46 accuracy 99.86252405828981 %
# Epoch 47 accuracy 99.89001924663185 %
# Epoch 48 accuracy 99.86252405828981 %
# Epoch 49 accuracy 99.86252405828981 %
# Epoch 50 accuracy 99.86252405828981 %
# Epoch 51 accuracy 99.86252405828981 %
# Epoch 52 accuracy 99.85335899550913 %
# Epoch 53 accuracy 99.20263953808085 %
# Epoch 54 accuracy 99.86252405828981 %
# Epoch 55 accuracy 99.89001924663185 %
# Epoch 56 accuracy 99.88085418385117 %
# Epoch 57 accuracy 99.89001924663185 %
# Epoch 58 accuracy 99.89001924663185 %
# Epoch 59 accuracy 99.9083493721932 %
# Epoch 60 accuracy 99.89001924663185 %
# Epoch 61 accuracy 99.68838786545687 %
# Epoch 62 accuracy 99.89001924663185 %
# Epoch 63 accuracy 99.89918430941252 %
# Epoch 64 accuracy 99.89918430941252 %
# Epoch 65 accuracy 99.6792228026762 %
# Epoch 66 accuracy 99.9083493721932 %
# Epoch 67 accuracy 99.84419393272844 %
# Epoch 68 accuracy 99.9083493721932 %
# Epoch 69 accuracy 99.9083493721932 %
# Epoch 70 accuracy 99.89918430941252 %
# Epoch 71 accuracy 99.89918430941252 %
# Epoch 72 accuracy 99.91751443497388 %
# Epoch 73 accuracy 99.89918430941252 %
# Epoch 74 accuracy 99.88085418385117 %
# Epoch 75 accuracy 99.88085418385117 %
# Epoch 76 accuracy 99.92667949775455 %
# Epoch 77 accuracy 99.92667949775455 %
# Epoch 78 accuracy 99.89001924663185 %
# Epoch 79 accuracy 99.89918430941252 %
# Epoch 80 accuracy 99.89001924663185 %
# Epoch 81 accuracy 99.9083493721932 %
# Epoch 82 accuracy 99.91751443497388 %
# Epoch 83 accuracy 99.89918430941252 %
# Epoch 84 accuracy 99.91751443497388 %
# Epoch 85 accuracy 99.9083493721932 %
# Epoch 86 accuracy 99.89001924663185 %
# Epoch 87 accuracy 99.89918430941252 %
# Epoch 88 accuracy 99.9083493721932 %
# Epoch 89 accuracy 99.91751443497388 %
# Epoch 90 accuracy 99.9083493721932 %
# Epoch 91 accuracy 99.91751443497388 %
# Epoch 92 accuracy 99.92667949775455 %
# Epoch 93 accuracy 99.9083493721932 %
# Epoch 94 accuracy 99.91751443497388 %
# Epoch 95 accuracy 99.91751443497388 %
# Epoch 96 accuracy 99.9083493721932 %
# Epoch 97 accuracy 99.89918430941252 %
# Epoch 98 accuracy 99.91751443497388 %
# Epoch 99 accuracy 99.89918430941252 %

# %%
pred_softmax = softmax_RICE.predict(X_train_RICE)
print('The training accuracy is given by: %f' % (get_acc(pred_softmax, y_train_RICE)))
# Out:
# The training accuracy is given by: 99.926679

# %% [markdown]
# ### Validate Softmax on Rice

# %%
pred_softmax = softmax_RICE.predict(X_val_RICE)
print('The validation accuracy is given by: %f' % (get_acc(pred_softmax, y_val_RICE)))
# Out:
# The validation accuracy is given by: 99.807534

# %% [markdown]
# ### Testing Softmax on Rice

# %%
pred_softmax = softmax_RICE.predict(X_test_RICE)
print('The testing accuracy is given by: %f' % (get_acc(pred_softmax, y_test_RICE)))
# Out:
# The testing accuracy is given by: 99.835029

# %% [markdown]
# # Logistic Classifier

# %% [markdown]
# The Logistic Classifier has 2 hyperparameters that you can experiment with:
# - **Learning rate** - similar to as defined above in Perceptron, this parameter scales by how much the weights are changed according to the calculated gradient update.
# - **Number of Epochs** - As described for perceptron.
# - **Threshold** - The decision boundary of the classifier.

# %% [markdown]
# You will implement the Logistic Classifier in the **models/logistic.py**
#
# The following code:
# - Creates an instance of the Logistic classifier class
# - The train function of the Logistic class is trained on the training data
# - We use the predict function to find the training accuracy as well as the testing accuracy

# %% [markdown]
# ### Training Logistic Classifer

# %%
learning_rate = 0.2
n_epochs = 40
threshold = 0.5

lr = Logistic(learning_rate, n_epochs, threshold)

# Refer to hints in the sigmoid and train methods of the Logistic class in "models/logistic.py"
lr.train(X_train_RICE, y_train_RICE)
# Out:
# [-0.00789158  0.0015046   0.00704861 -0.00834266 -0.00870193 -0.00811359
#  -0.00476959  0.00066374  0.00517153  0.00941171  0.00484157]
# /home/abhsas/Documents/cs444/sp25_assignment1/assignment1/models/logistic.py:31: RuntimeWarning: overflow encountered in exp
#   return np.where(z >=0 , 1/(1 + np.exp(-z)), np.exp(z)/ (1+np.exp(z)))
# /home/abhsas/Documents/cs444/sp25_assignment1/assignment1/models/logistic.py:31: RuntimeWarning: invalid value encountered in divide
#   return np.where(z >=0 , 1/(1 + np.exp(-z)), np.exp(z)/ (1+np.exp(z)))

# %%
pred_lr = lr.predict(X_train_RICE)
print('The training accuracy is given by: %f' % (get_acc(pred_lr, y_train_RICE)))
# Out:
# The training accuracy is given by: 98.231143

# %% [markdown]
# ### Validate Logistic Classifer

# %%
pred_lr = lr.predict(X_val_RICE)
print('The validation accuracy is given by: %f' % (get_acc(pred_lr, y_val_RICE)))
# Out:
# The validation accuracy is given by: 98.240308

# %% [markdown]
# ### Test Logistic Classifier

# %%
pred_lr = lr.predict(X_test_RICE)
print('The testing accuracy is given by: %f' % (get_acc(pred_lr, y_test_RICE)))
# Out:
# The testing accuracy is given by: 98.322794
