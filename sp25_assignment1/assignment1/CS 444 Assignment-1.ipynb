# %% [markdown]
# # Imports

# %%
import random
import numpy as np
from data_process import get_FASHION_data, get_RICE_data
from scipy.spatial import distance
from models import Perceptron, SVM, Softmax, Logistic
from kaggle_submission import output_submission_csv
# %matplotlib inline

# For auto-reloading external modules
# See http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Loading Fashion-MNIST

# %% [markdown]
# In the following cells we determine the number of images for each split and load the images.
# <br />
# TRAIN_IMAGES + VAL_IMAGES = (0, 60000]
# , TEST_IMAGES = 10000

# %%
# You can change these numbers for experimentation
# For submission we will use the default values 
TRAIN_IMAGES = 50000
VAL_IMAGES = 10000
normalize = True

# %%
data = get_FASHION_data(TRAIN_IMAGES, VAL_IMAGES, normalize=normalize)
X_train_fashion, y_train_fashion = data['X_train'], data['y_train']
X_val_fashion, y_val_fashion = data['X_val'], data['y_val']
X_test_fashion, y_test_fashion = data['X_test'], data['y_test']
n_class_fashion = len(np.unique(y_test_fashion))

# %% [markdown]
# # Loading Rice

# %%
# loads train / test / val splits of 80%, 20%, 20% 
data = get_RICE_data()
X_train_RICE, y_train_RICE = data['X_train'], data['y_train']
X_val_RICE, y_val_RICE = data['X_val'], data['y_val']
X_test_RICE, y_test_RICE = data['X_test'], data['y_test']
n_class_RICE = len(np.unique(y_test_RICE))

print("Number of train samples: ", X_train_RICE.shape[0])
print("Number of val samples: ", X_val_RICE.shape[0])
print("Number of test samples: ", X_test_RICE.shape[0])
# Out:
# Number of train samples:  10911
# Number of val samples:  3637
# Number of test samples:  3637

# %% [markdown]
# ### Get Accuracy

# %% [markdown]
# This function computes how well your model performs using accuracy as a metric.

# %%
def get_acc(pred, y_test):
    return np.sum(y_test == pred) / len(y_test) * 100

# %% [markdown]
# # Perceptron

# %% [markdown]
# Perceptron has 2 hyperparameters, "learning rate" and "number of epochs" that you can experiment with:
# ### Hyperparameter 1: Learning rate
# The learning rate controls how much we change the current weights of the classifier during each update. We set it at a default value of 0.5, but you should experiment with different values. Here is a guide to help you find a right learning rate:
# - Try values ranging from 0.0005 to 5.0 to see the impact on model accuracy.
# - If the loss oscillates a lot or the loss diverges, the learning rate may be too high. Try decreasing it by a factor of 10 (e.g. from 0.5 to 0.05).
# - If the loss decreases very slowly, the learning rate may be too low and the training can take a long time. Try increasing it by a factor of 10.
# - You can also try adding a learning rate decay to slowly reduce the learning rate over each training epoch. For example, multiply the learning rate by 0.95 after each epoch.
# - Plot training and validation accuracy over epochs for different learning rates. This will help you visualize the impact of the learning rate.
# - [Here](https://towardsdatascience.com/https-medium-com-dashingaditya-rakhecha-understanding-learning-rate-dd5da26bb6de) is a detailed guide to learning rate.
#
# ### Hyperparameter 2: Number of Epochs
# - An epoch is a complete iterative pass over the training dataset. During an epoch we predict a label using the classifier and then update the weights of the classifier according to the perceptron update rule for each sample in the training set.
# - By observing the training and validation accuracy graphs, you can determine if the model has converged or not. Try increasing the number of epochs if the model is not converging or has low accuracy.
# - You should try different values for the number of training epochs and report your results.

# %% [markdown]
# In this section, you will implement the Perceptron classifier in the **models/perceptron.py** script.
#
# The following code:
# - Creates an instance of the Perceptron classifier class
# - An instance of the Perceptron class is trained on the training data using its train method.
# - We use the predict method to find the training accuracy as well as the testing accuracy

# %% [markdown]
# ## Train Perceptron on Fashion-MNIST

# %%
lr = 0.4
n_epochs = 27
batch_size = 500
percept_fashion = Perceptron(n_class_fashion, lr, n_epochs, batch_size)

# - Refer to hints in the train method of the Perceptron class in "models/perceptron.py"
percept_fashion.train(X_train_fashion, y_train_fashion)
# Out:
# Epoch 0 accuracy 13.350000000000001 %
# Epoch 1 accuracy 72.44800000000001 %
# Epoch 2 accuracy 82.506 %
# Epoch 3 accuracy 83.012 %
# Epoch 4 accuracy 78.782 %
# Epoch 5 accuracy 81.804 %
# Epoch 6 accuracy 66.106 %
# Epoch 7 accuracy 80.47999999999999 %
# Epoch 8 accuracy 84.614 %
# Epoch 9 accuracy 82.572 %
# Epoch 10 accuracy 81.842 %
# Epoch 11 accuracy 79.646 %
# Epoch 12 accuracy 84.354 %
# Epoch 13 accuracy 81.164 %
# Epoch 14 accuracy 83.28 %
# Epoch 15 accuracy 83.378 %
# Epoch 16 accuracy 78.63 %
# Epoch 17 accuracy 79.36800000000001 %
# Epoch 18 accuracy 83.38600000000001 %
# Epoch 19 accuracy 83.552 %
# Epoch 20 accuracy 83.194 %
# Epoch 21 accuracy 78.666 %
# Epoch 22 accuracy 84.86399999999999 %
# Epoch 23 accuracy 82.328 %
# Epoch 24 accuracy 78.266 %
# Epoch 25 accuracy 84.55799999999999 %
# Epoch 26 accuracy 76.726 %

# %%
pred_percept = percept_fashion.predict(X_train_fashion)
print('The training accuracy is given by: %f' % (get_acc(pred_percept, y_train_fashion)))
# Out:
# The training accuracy is given by: 84.440000

# %% [markdown]
# ### Validate Perceptron on Fashion-MNIST

# %%
pred_percept = percept_fashion.predict(X_val_fashion)
print('The validation accuracy is given by: %f' % (get_acc(pred_percept, y_val_fashion)))
# Out:
# The validation accuracy is given by: 82.370000

# %% [markdown]
# ### Test Perceptron on Fashion-MNIST

# %%
pred_percept = percept_fashion.predict(X_test_fashion)
print('The testing accuracy is given by: %f' % (get_acc(pred_percept, y_test_fashion)))
# Out:
# The testing accuracy is given by: 81.600000

# %% [markdown]
# ### Perceptron_Fashion-MNIST Kaggle Submission
#
# Once you are satisfied with your solution and test accuracy, output a file to submit your test set predictions to the Kaggle for Assignment 1 Fashion-MNIST. Use the following code to do so:

# %%
output_submission_csv('kaggle/perceptron_submission_fashion.csv', percept_fashion.predict(X_test_fashion))

# %% [markdown]
# ## Train Perceptron on Rice

# %%
lr = 0.4
n_epochs = 27
batch_size = 20

percept_RICE = Perceptron(n_class_RICE, lr, n_epochs, batch_size)
percept_RICE.train(X_train_RICE, y_train_RICE)
# Out:
# Epoch 0 accuracy 29.914764916139674 %
# Epoch 1 accuracy 75.34598111997067 %
# Epoch 2 accuracy 70.86426542021813 %
# Epoch 3 accuracy 79.75437631747778 %
# Epoch 4 accuracy 80.46008615159013 %
# Epoch 5 accuracy 81.6240491247365 %
# Epoch 6 accuracy 81.6698744386399 %
# Epoch 7 accuracy 81.26661167628998 %
# Epoch 8 accuracy 77.56392631289525 %
# Epoch 9 accuracy 84.57519934011547 %
# Epoch 10 accuracy 66.78581248281552 %
# Epoch 11 accuracy 79.40610393181193 %
# Epoch 12 accuracy 88.55283658693061 %
# Epoch 13 accuracy 70.99257629914764 %
# Epoch 14 accuracy 84.49271377508936 %
# Epoch 15 accuracy 74.65860141141967 %
# Epoch 16 accuracy 89.55182843002476 %
# Epoch 17 accuracy 74.77774722756851 %
# Epoch 18 accuracy 82.92548803959308 %
# Epoch 19 accuracy 88.5161763358079 %
# Epoch 20 accuracy 86.20658051507652 %
# Epoch 21 accuracy 73.88873613784254 %
# Epoch 22 accuracy 69.79195307487856 %
# Epoch 23 accuracy 91.2748602327926 %
# Epoch 24 accuracy 96.11401338099166 %
# Epoch 25 accuracy 80.35927046100267 %
# Epoch 26 accuracy 88.71780771698286 %

# %%
pred_percept = percept_RICE.predict(X_train_RICE)
print('The training accuracy is given by: %f' % (get_acc(pred_percept, y_train_RICE)))
# Out:
# The training accuracy is given by: 93.236184

# %% [markdown]
# ### Validate Perceptron on Rice

# %%
pred_percept = percept_RICE.predict(X_val_RICE)
print('The validation accuracy is given by: %f' % (get_acc(pred_percept, y_val_RICE)))
# Out:
# The validation accuracy is given by: 93.456145

# %% [markdown]
# ### Test Perceptron on Rice

# %%
pred_percept = percept_RICE.predict(X_test_RICE)
print('The testing accuracy is given by: %f' % (get_acc(pred_percept, y_test_RICE)))
# Out:
# The testing accuracy is given by: 93.483640

# %% [markdown]
# # Support Vector Machines (with SGD)

# %% [markdown]
# Next, you will implement a "soft margin" SVM. In this formulation you will maximize the margin between positive and negative training examples and penalize margin violations using a hinge loss.
#
# We will optimize the SVM loss using SGD. This means you must compute the loss function with respect to model weights. You will use this gradient to update the model weights.
#
# SVM optimized with SGD has 3 hyperparameters that you can experiment with:
# - **Learning rate** - similar to as defined above in Perceptron, this parameter scales by how much the weights are changed according to the calculated gradient update.
# - **Epochs** - similar to as defined above in Perceptron.
# - **Regularization constant** - Hyperparameter to determine the strength of regularization. In this case it is a coefficient on the term which maximizes the margin. You could try different values. The default value is set to 0.05.

# %% [markdown]
# You will implement the SVM using SGD in the **models/svm.py**
#
# The following code:
# - Creates an instance of the SVM classifier class
# - The train function of the SVM class is trained on the training data
# - We use the predict function to find the training accuracy as well as the testing accuracy

# %% [markdown]
# ## Train SVM on Fashion-MNIST

# %%
# Adjust the following three hyperparameters to achieve the best accuracy:
lr = 0.5
n_epochs = 15
reg_const = 0.05
batch_size=500

svm_fashion = SVM(n_class_fashion, lr, n_epochs, reg_const,batch_size)

# Refer to hints in the calculate_gradient and train methods of the SVM class in "models/svm.py"
svm_fashion.train(X_train_fashion, y_train_fashion)
# Out:
# Epoch 0 accuracy 6.106 %
# Epoch 1 accuracy 73.27799999999999 %
# Epoch 2 accuracy 67.414 %
# Epoch 3 accuracy 72.32 %
# Epoch 4 accuracy 63.032 %
# Epoch 5 accuracy 74.708 %
# Epoch 6 accuracy 79.36 %
# Epoch 7 accuracy 68.93599999999999 %
# Epoch 8 accuracy 81.028 %
# Epoch 9 accuracy 83.408 %
# Epoch 10 accuracy 79.42 %
# Epoch 11 accuracy 81.272 %
# Epoch 12 accuracy 80.026 %
# Epoch 13 accuracy 84.824 %
# Epoch 14 accuracy 84.976 %

# %%
pred_svm = svm_fashion.predict(X_train_fashion)
print('The training accuracy is given by: %f' % (get_acc(pred_svm, y_train_fashion)))
# Out:
# The training accuracy is given by: 85.170000

# %% [markdown]
# ### Validate SVM on Fashion-MNIST

# %%
pred_svm = svm_fashion.predict(X_val_fashion)
print('The validation accuracy is given by: %f' % (get_acc(pred_svm, y_val_fashion)))
# Out:
# The validation accuracy is given by: 83.090000

# %% [markdown]
# ### Test SVM on Fashion-MNIST

# %%
pred_svm = svm_fashion.predict(X_test_fashion)
print('The testing accuracy is given by: %f' % (get_acc(pred_svm, y_test_fashion)))
# Out:
# The testing accuracy is given by: 81.700000

# %% [markdown]
# ### SVM_Fashion-MNIST Kaggle Submission
#
# Once you are satisfied with your solution and test accuracy output a file to submit your test set predictions to the Kaggle for Assignment 1 Fashion-MNIST. Use the following code to do so:

# %%
output_submission_csv('kaggle/svm_submission_fashion.csv', svm_fashion.predict(X_test_fashion))

# %% [markdown]
# ## Train SVM on Rice

# %%
# Adjust the following three hyperparameters to achieve the best accuracy: 
lr = 0.5
n_epochs = 20
reg_const = 0.05
batch_size=100
svm_RICE = SVM(n_class_RICE, lr, n_epochs, reg_const, batch_size)
svm_RICE.train(X_train_RICE, y_train_RICE)
# Out:
# Epoch 0 accuracy 54.541288607826964 %
# Epoch 1 accuracy 54.972046558518926 %
# Epoch 2 accuracy 79.25946292732105 %
# Epoch 3 accuracy 72.9447346714325 %
# Epoch 4 accuracy 77.52726606177252 %
# Epoch 5 accuracy 77.48144074786913 %
# Epoch 6 accuracy 68.9945926129594 %
# Epoch 7 accuracy 61.77252314178352 %
# Epoch 8 accuracy 75.47429199890018 %
# Epoch 9 accuracy 78.20548070754285 %
# Epoch 10 accuracy 79.30528824122445 %
# Epoch 11 accuracy 81.72486481532398 %
# Epoch 12 accuracy 82.19228301713866 %
# Epoch 13 accuracy 70.77261479241133 %
# Epoch 14 accuracy 87.22390248373202 %
# Epoch 15 accuracy 83.34708092750435 %
# Epoch 16 accuracy 77.23398405279076 %
# Epoch 17 accuracy 99.46842635872055 %
# Epoch 18 accuracy 99.74337824214096 %
# Epoch 19 accuracy 99.78920355604436 %

# %%
pred_svm = svm_RICE.predict(X_train_RICE)
print('The training accuracy is given by: %f' % (get_acc(pred_svm, y_train_RICE)))
# Out:
# The training accuracy is given by: 99.825864

# %% [markdown]
# ### Validate SVM on Rice

# %%
pred_svm = svm_RICE.predict(X_val_RICE)
print('The validation accuracy is given by: %f' % (get_acc(pred_svm, y_val_RICE)))
# Out:
# The validation accuracy is given by: 99.697553

# %% [markdown]
# ## Test SVM on Rice

# %%
pred_svm = svm_RICE.predict(X_test_RICE)
print('The testing accuracy is given by: %f' % (get_acc(pred_svm, y_test_RICE)))
# Out:
# The testing accuracy is given by: 99.752543

# %% [markdown]
# # Softmax Classifier (with SGD)

# %% [markdown]
# Next, you will train a Softmax classifier. This classifier consists of a linear function of the input data followed by a softmax function which outputs a vector of dimension C (number of classes) for each data point. Each entry of the softmax output vector corresponds to a confidence in one of the C classes, and like a probability distribution, the entries of the output vector sum to 1. We use a cross-entropy loss on this sotmax output to train the model.
#
# Check the following link as an additional resource on softmax classification: http://cs231n.github.io/linear-classify/#softmax
#
# Once again we will train the classifier with SGD. This means you need to compute the gradients of the softmax cross-entropy loss function according to the weights and update the weights using this gradient. Check the following link to help with implementing the gradient updates: https://deepnotes.io/softmax-crossentropy

# %% [markdown]
# The softmax classifier has 3 hyperparameters that you can experiment with:
# - **Learning rate** - As above, this controls how much the model weights are updated with respect to their gradient.
# - **Number of Epochs** - As described for perceptron.
# - **Regularization constant** - Hyperparameter to determine the strength of regularization. In this case, we minimize the L2 norm of the model weights as regularization, so the regularization constant is a coefficient on the L2 norm in the combined cross-entropy and regularization objective.

# %% [markdown]
# You will implement a softmax classifier using SGD in the **models/softmax.py**
#
# The following code:
# - Creates an instance of the Softmax classifier class
# - The train function of the Softmax class is trained on the training data
# - We use the predict function to find the training accuracy as well as the testing accuracy

# %% [markdown]
# ## Train Softmax on Fashion-MNIST

# %%
lr = 0.001
n_epochs = 200
reg_const = 0.7
batch_size=128
softmax_fashion = Softmax(n_class_fashion, lr, n_epochs, reg_const, batch_size)

# Refer to hints in the calculate_gradient and train methods of the Softmax class in "models/softmax.py"
softmax_fashion.train(X_train_fashion, y_train_fashion)
# Out:
# Epoch 0 accuracy 5.772 %
# Epoch 1 accuracy 80.084 %
# Epoch 2 accuracy 74.68 %
# Epoch 3 accuracy 80.4 %
# Epoch 4 accuracy 73.618 %
# Epoch 5 accuracy 74.122 %
# Epoch 6 accuracy 77.236 %
# Epoch 7 accuracy 77.166 %
# Epoch 8 accuracy 81.316 %
# Epoch 9 accuracy 73.09 %
# Epoch 10 accuracy 72.196 %
# Epoch 11 accuracy 83.086 %
# Epoch 12 accuracy 82.002 %
# Epoch 13 accuracy 68.35799999999999 %
# Epoch 14 accuracy 74.112 %
# Epoch 15 accuracy 80.53200000000001 %
# Epoch 16 accuracy 80.888 %
# Epoch 17 accuracy 82.904 %
# Epoch 18 accuracy 82.196 %
# Epoch 19 accuracy 77.114 %
# Epoch 20 accuracy 80.972 %
# Epoch 21 accuracy 77.084 %
# Epoch 22 accuracy 81.53200000000001 %
# Epoch 23 accuracy 83.516 %
# Epoch 24 accuracy 81.746 %
# Epoch 25 accuracy 81.164 %
# Epoch 26 accuracy 77.534 %
# Epoch 27 accuracy 81.87 %
# Epoch 28 accuracy 74.42999999999999 %
# Epoch 29 accuracy 77.11200000000001 %
# Epoch 30 accuracy 76.62 %
# Epoch 31 accuracy 81.258 %
# Epoch 32 accuracy 75.776 %
# Epoch 33 accuracy 79.334 %
# Epoch 34 accuracy 73.792 %
# Epoch 35 accuracy 81.016 %
# Epoch 36 accuracy 80.552 %
# Epoch 37 accuracy 81.814 %
# Epoch 38 accuracy 78.536 %
# Epoch 39 accuracy 76.28399999999999 %
# Epoch 40 accuracy 83.816 %
# Epoch 41 accuracy 81.348 %
# Epoch 42 accuracy 81.69 %
# Epoch 43 accuracy 83.724 %
# Epoch 44 accuracy 79.752 %
# Epoch 45 accuracy 85.166 %
# Epoch 46 accuracy 79.462 %
# Epoch 47 accuracy 82.114 %
# Epoch 48 accuracy 84.536 %
# Epoch 49 accuracy 81.584 %
# Epoch 50 accuracy 83.028 %
# Epoch 51 accuracy 77.018 %
# Epoch 52 accuracy 78.304 %
# Epoch 53 accuracy 85.75399999999999 %
# Epoch 54 accuracy 84.04 %
# Epoch 55 accuracy 80.674 %
# Epoch 56 accuracy 82.96 %
# Epoch 57 accuracy 84.25 %
# Epoch 58 accuracy 81.716 %
# Epoch 59 accuracy 83.906 %
# Epoch 60 accuracy 83.866 %
# Epoch 61 accuracy 84.148 %
# Epoch 62 accuracy 80.194 %
# Epoch 63 accuracy 84.902 %
# Epoch 64 accuracy 83.282 %
# Epoch 65 accuracy 86.866 %
# Epoch 66 accuracy 87.09599999999999 %
# Epoch 67 accuracy 79.486 %
# Epoch 68 accuracy 85.09 %
# Epoch 69 accuracy 83.762 %
# Epoch 70 accuracy 85.008 %
# Epoch 71 accuracy 86.83800000000001 %
# Epoch 72 accuracy 85.00999999999999 %
# Epoch 73 accuracy 86.968 %
# Epoch 74 accuracy 84.506 %
# Epoch 75 accuracy 86.86399999999999 %
# Epoch 76 accuracy 86.994 %
# Epoch 77 accuracy 85.788 %
# Epoch 78 accuracy 86.76 %
# Epoch 79 accuracy 86.37599999999999 %
# Epoch 80 accuracy 86.554 %
# Epoch 81 accuracy 85.86399999999999 %
# Epoch 82 accuracy 87.52600000000001 %
# Epoch 83 accuracy 86.15 %
# Epoch 84 accuracy 87.846 %
# Epoch 85 accuracy 86.56 %
# Epoch 86 accuracy 87.874 %
# Epoch 87 accuracy 87.468 %
# Epoch 88 accuracy 87.71 %
# Epoch 89 accuracy 87.602 %
# Epoch 90 accuracy 87.40599999999999 %
# Epoch 91 accuracy 87.274 %
# Epoch 92 accuracy 87.28399999999999 %
# Epoch 93 accuracy 88.134 %
# Epoch 94 accuracy 87.702 %
# Epoch 95 accuracy 87.958 %
# Epoch 96 accuracy 87.88 %
# Epoch 97 accuracy 88.228 %
# Epoch 98 accuracy 88.28 %
# Epoch 99 accuracy 87.956 %
# Epoch 100 accuracy 88.26 %
# Epoch 101 accuracy 88.336 %
# Epoch 102 accuracy 88.112 %
# Epoch 103 accuracy 87.576 %
# Epoch 104 accuracy 88.18 %
# Epoch 105 accuracy 88.378 %
# Epoch 106 accuracy 87.91 %
# Epoch 107 accuracy 87.994 %
# Epoch 108 accuracy 88.506 %
# Epoch 109 accuracy 88.48 %
# Epoch 110 accuracy 88.352 %
# Epoch 111 accuracy 88.44 %
# Epoch 112 accuracy 88.486 %
# Epoch 113 accuracy 88.368 %
# Epoch 114 accuracy 88.348 %
# Epoch 115 accuracy 88.426 %
# Epoch 116 accuracy 88.396 %
# Epoch 117 accuracy 88.412 %
# Epoch 118 accuracy 88.276 %
# Epoch 119 accuracy 88.32600000000001 %
# Epoch 120 accuracy 88.33 %
# Epoch 121 accuracy 88.354 %
# Epoch 122 accuracy 88.484 %
# Epoch 123 accuracy 88.402 %
# Epoch 124 accuracy 88.41799999999999 %
# Epoch 125 accuracy 88.41799999999999 %
# Epoch 126 accuracy 88.51400000000001 %
# Epoch 127 accuracy 88.34 %
# Epoch 128 accuracy 88.506 %
# Epoch 129 accuracy 88.536 %
# Epoch 130 accuracy 88.5 %
# Epoch 131 accuracy 88.47 %
# Epoch 132 accuracy 88.52600000000001 %
# Epoch 133 accuracy 88.496 %
# Epoch 134 accuracy 88.424 %
# Epoch 135 accuracy 88.534 %
# Epoch 136 accuracy 88.508 %
# Epoch 137 accuracy 88.53999999999999 %
# Epoch 138 accuracy 88.536 %
# Epoch 139 accuracy 88.51400000000001 %
# Epoch 140 accuracy 88.536 %
# Epoch 141 accuracy 88.49000000000001 %
# Epoch 142 accuracy 88.478 %
# Epoch 143 accuracy 88.504 %
# Epoch 144 accuracy 88.512 %
# Epoch 145 accuracy 88.518 %
# Epoch 146 accuracy 88.548 %
# Epoch 147 accuracy 88.512 %
# Epoch 148 accuracy 88.508 %
# Epoch 149 accuracy 88.546 %
# Epoch 150 accuracy 88.444 %
# Epoch 151 accuracy 88.488 %
# Epoch 152 accuracy 88.51 %
# Epoch 153 accuracy 88.484 %
# Epoch 154 accuracy 88.558 %
# Epoch 155 accuracy 88.52 %
# Epoch 156 accuracy 88.478 %
# Epoch 157 accuracy 88.51 %
# Epoch 158 accuracy 88.52799999999999 %
# Epoch 159 accuracy 88.472 %
# Epoch 160 accuracy 88.48 %
# Epoch 161 accuracy 88.5 %
# Epoch 162 accuracy 88.488 %
# Epoch 163 accuracy 88.51400000000001 %
# Epoch 164 accuracy 88.512 %
# Epoch 165 accuracy 88.508 %
# Epoch 166 accuracy 88.524 %
# Epoch 167 accuracy 88.50200000000001 %
# Epoch 168 accuracy 88.522 %
# Epoch 169 accuracy 88.51400000000001 %
# Epoch 170 accuracy 88.532 %
# Epoch 171 accuracy 88.482 %
# Epoch 172 accuracy 88.478 %
# Epoch 173 accuracy 88.494 %
# Epoch 174 accuracy 88.504 %
# Epoch 175 accuracy 88.51400000000001 %
# Epoch 176 accuracy 88.51 %
# Epoch 177 accuracy 88.50200000000001 %
# Epoch 178 accuracy 88.50200000000001 %
# Epoch 179 accuracy 88.51599999999999 %
# Epoch 180 accuracy 88.488 %
# Epoch 181 accuracy 88.51599999999999 %
# Epoch 182 accuracy 88.51599999999999 %
# Epoch 183 accuracy 88.508 %
# Epoch 184 accuracy 88.508 %
# Epoch 185 accuracy 88.524 %
# Epoch 186 accuracy 88.51599999999999 %
# Epoch 187 accuracy 88.498 %
# Epoch 188 accuracy 88.504 %
# Epoch 189 accuracy 88.52600000000001 %
# Epoch 190 accuracy 88.496 %
# Epoch 191 accuracy 88.51400000000001 %
# Epoch 192 accuracy 88.51599999999999 %
# Epoch 193 accuracy 88.508 %
# Epoch 194 accuracy 88.506 %
# Epoch 195 accuracy 88.508 %
# Epoch 196 accuracy 88.512 %
# Epoch 197 accuracy 88.496 %
# Epoch 198 accuracy 88.498 %
# Epoch 199 accuracy 88.49000000000001 %

# %%
pred_softmax = softmax_fashion.predict(X_train_fashion)
print('The training accuracy is given by: %f' % (get_acc(pred_softmax, y_train_fashion)))
# Out:
# The training accuracy is given by: 88.494000

# %% [markdown]
# ### Validate Softmax on Fashion-MNIST

# %%
pred_softmax = softmax_fashion.predict(X_val_fashion)
print('The validation accuracy is given by: %f' % (get_acc(pred_softmax, y_val_fashion)))
# Out:
# The validation accuracy is given by: 84.040000

# %% [markdown]
# ### Testing Softmax on Fashion-MNIST

# %%
pred_softmax = softmax_fashion.predict(X_test_fashion)
print('The testing accuracy is given by: %f' % (get_acc(pred_softmax, y_test_fashion)))
# Out:
# The testing accuracy is given by: 83.070000

# %% [markdown]
# ### Softmax_Fashion-MNIST Kaggle Submission
#
# Once you are satisfied with your solution and test accuracy output a file to submit your test set predictions to the Kaggle for Assignment 1 Fashion-MNIST. Use the following code to do so:

# %%
output_submission_csv('kaggle/softmax_submission_fashion.csv', softmax_fashion.predict(X_test_fashion))

# %% [markdown]
# ## Train Softmax on Rice

# %%
lr = 0.001
n_epochs = 100
reg_const = 0.5
batch_size = 128

softmax_RICE = Softmax(n_class_RICE, lr, n_epochs, reg_const, batch_size)
softmax_RICE.train(X_train_RICE, y_train_RICE)
# Out:
# Epoch 0 accuracy 54.779580240124645 %
# Epoch 1 accuracy 65.25524699844195 %
# Epoch 2 accuracy 75.74007881953992 %
# Epoch 3 accuracy 76.940702043809 %
# Epoch 4 accuracy 78.60874346989277 %
# Epoch 5 accuracy 72.81642379250299 %
# Epoch 6 accuracy 74.5944459719549 %
# Epoch 7 accuracy 57.437448446521856 %
# Epoch 8 accuracy 59.30712125378059 %
# Epoch 9 accuracy 76.47328384199432 %
# Epoch 10 accuracy 78.23297589588488 %
# Epoch 11 accuracy 54.81624049124737 %
# Epoch 12 accuracy 78.31546146091101 %
# Epoch 13 accuracy 61.13096874713592 %
# Epoch 14 accuracy 78.55375309320868 %
# Epoch 15 accuracy 63.440564567867284 %
# Epoch 16 accuracy 77.0323526716158 %
# Epoch 17 accuracy 81.0741453578957 %
# Epoch 18 accuracy 82.09146732655118 %
# Epoch 19 accuracy 80.00183301255613 %
# Epoch 20 accuracy 80.09348364036293 %
# Epoch 21 accuracy 55.92521308770964 %
# Epoch 22 accuracy 82.39391439831363 %
# Epoch 23 accuracy 60.01283108789295 %
# Epoch 24 accuracy 82.66886628173403 %
# Epoch 25 accuracy 82.8613326001283 %
# Epoch 26 accuracy 83.03546879296123 %
# Epoch 27 accuracy 81.55989368527175 %
# Epoch 28 accuracy 84.4285583356246 %
# Epoch 29 accuracy 85.38172486481533 %
# Epoch 30 accuracy 66.18091833929063 %
# Epoch 31 accuracy 49.7021354596279 %
# Epoch 32 accuracy 75.13518467601503 %
# Epoch 33 accuracy 82.42140958665567 %
# Epoch 34 accuracy 87.4163688021263 %
# Epoch 35 accuracy 87.26056273485473 %
# Epoch 36 accuracy 88.6994775914215 %
# Epoch 37 accuracy 69.50783612867748 %
# Epoch 38 accuracy 75.11685455045367 %
# Epoch 39 accuracy 47.722481899001004 %
# Epoch 40 accuracy 77.57309137567593 %
# Epoch 41 accuracy 87.24223260929337 %
# Epoch 42 accuracy 88.02126294565117 %
# Epoch 43 accuracy 95.45412886078269 %
# Epoch 44 accuracy 99.23013472642288 %
# Epoch 45 accuracy 99.80753368160572 %
# Epoch 46 accuracy 99.86252405828981 %
# Epoch 47 accuracy 99.87168912107049 %
# Epoch 48 accuracy 99.56924204930803 %
# Epoch 49 accuracy 99.89918430941252 %
# Epoch 50 accuracy 99.86252405828981 %
# Epoch 51 accuracy 99.37677573091376 %
# Epoch 52 accuracy 99.88085418385117 %
# Epoch 53 accuracy 99.89001924663185 %
# Epoch 54 accuracy 99.86252405828981 %
# Epoch 55 accuracy 99.85335899550913 %
# Epoch 56 accuracy 99.89918430941252 %
# Epoch 57 accuracy 99.89918430941252 %
# Epoch 58 accuracy 99.9083493721932 %
# Epoch 59 accuracy 99.71588305379892 %
# Epoch 60 accuracy 99.91751443497388 %
# Epoch 61 accuracy 99.9083493721932 %
# Epoch 62 accuracy 99.6792228026762 %
# Epoch 63 accuracy 99.89918430941252 %
# Epoch 64 accuracy 99.91751443497388 %
# Epoch 65 accuracy 99.89918430941252 %
# Epoch 66 accuracy 99.86252405828981 %
# Epoch 67 accuracy 99.86252405828981 %
# Epoch 68 accuracy 99.87168912107049 %
# Epoch 69 accuracy 99.91751443497388 %
# Epoch 70 accuracy 99.88085418385117 %
# Epoch 71 accuracy 99.9083493721932 %
# Epoch 72 accuracy 99.88085418385117 %
# Epoch 73 accuracy 99.91751443497388 %
# Epoch 74 accuracy 99.88085418385117 %
# Epoch 75 accuracy 99.91751443497388 %
# Epoch 76 accuracy 99.92667949775455 %
# Epoch 77 accuracy 99.89001924663185 %
# Epoch 78 accuracy 99.85335899550913 %
# Epoch 79 accuracy 99.91751443497388 %
# Epoch 80 accuracy 99.88085418385117 %
# Epoch 81 accuracy 99.91751443497388 %
# Epoch 82 accuracy 99.89918430941252 %
# Epoch 83 accuracy 99.92667949775455 %
# Epoch 84 accuracy 99.89001924663185 %
# Epoch 85 accuracy 99.91751443497388 %
# Epoch 86 accuracy 99.88085418385117 %
# Epoch 87 accuracy 99.89001924663185 %
# Epoch 88 accuracy 99.91751443497388 %
# Epoch 89 accuracy 99.89001924663185 %
# Epoch 90 accuracy 99.9083493721932 %
# Epoch 91 accuracy 99.9083493721932 %
# Epoch 92 accuracy 99.91751443497388 %
# Epoch 93 accuracy 99.91751443497388 %
# Epoch 94 accuracy 99.83502886994776 %
# Epoch 95 accuracy 99.92667949775455 %
# Epoch 96 accuracy 99.91751443497388 %
# Epoch 97 accuracy 99.91751443497388 %
# Epoch 98 accuracy 99.91751443497388 %
# Epoch 99 accuracy 99.92667949775455 %

# %%
pred_softmax = softmax_RICE.predict(X_train_RICE)
print('The training accuracy is given by: %f' % (get_acc(pred_softmax, y_train_RICE)))
# Out:
# The training accuracy is given by: 99.926679

# %% [markdown]
# ### Validate Softmax on Rice

# %%
pred_softmax = softmax_RICE.predict(X_val_RICE)
print('The validation accuracy is given by: %f' % (get_acc(pred_softmax, y_val_RICE)))
# Out:
# The validation accuracy is given by: 99.807534

# %% [markdown]
# ### Testing Softmax on Rice

# %%
pred_softmax = softmax_RICE.predict(X_test_RICE)
print('The testing accuracy is given by: %f' % (get_acc(pred_softmax, y_test_RICE)))
# Out:
# The testing accuracy is given by: 99.835029

# %% [markdown]
# # Logistic Classifier

# %% [markdown]
# The Logistic Classifier has 2 hyperparameters that you can experiment with:
# - **Learning rate** - similar to as defined above in Perceptron, this parameter scales by how much the weights are changed according to the calculated gradient update.
# - **Number of Epochs** - As described for perceptron.
# - **Threshold** - The decision boundary of the classifier.

# %% [markdown]
# You will implement the Logistic Classifier in the **models/logistic.py**
#
# The following code:
# - Creates an instance of the Logistic classifier class
# - The train function of the Logistic class is trained on the training data
# - We use the predict function to find the training accuracy as well as the testing accuracy

# %% [markdown]
# ### Training Logistic Classifer

# %%
learning_rate = 0.2
n_epochs = 40
threshold = 0.5

lr = Logistic(learning_rate, n_epochs, threshold)

# Refer to hints in the sigmoid and train methods of the Logistic class in "models/logistic.py"
lr.train(X_train_RICE, y_train_RICE)
# Out:
# /home/abhsas/Documents/cs444/sp25_assignment1/assignment1/models/logistic.py:34: RuntimeWarning: overflow encountered in exp
#   return np.where(z >= 0, 1/(1 + np.exp(-z)), np.exp(z) / (1+np.exp(z)))
# /home/abhsas/Documents/cs444/sp25_assignment1/assignment1/models/logistic.py:34: RuntimeWarning: invalid value encountered in divide
#   return np.where(z >= 0, 1/(1 + np.exp(-z)), np.exp(z) / (1+np.exp(z)))
# [-0.00828951  0.00641555 -0.00932225  0.00420873  0.00116508  0.00470696
#   0.00179247 -0.00993093 -0.00270843  0.00833246 -0.00246877]

# %%
pred_lr = lr.predict(X_train_RICE)
print('The training accuracy is given by: %f' % (get_acc(pred_lr, y_train_RICE)))
# Out:
# The training accuracy is given by: 98.707726

# %% [markdown]
# ### Validate Logistic Classifer

# %%
pred_lr = lr.predict(X_val_RICE)
print('The validation accuracy is given by: %f' % (get_acc(pred_lr, y_val_RICE)))
# Out:
# The validation accuracy is given by: 98.652736

# %% [markdown]
# ### Test Logistic Classifier

# %%
pred_lr = lr.predict(X_test_RICE)
print('The testing accuracy is given by: %f' % (get_acc(pred_lr, y_test_RICE)))
# Out:
# The testing accuracy is given by: 98.680231
